# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/3, OCD.csv'
filename_clean = '../csv_detection_info_clean/3, OCD.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/3, OCD'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0           1.2.276.0.95.17743.20210223.94114.0.0.dcm      736      937
# 1   1.2.276.0.95.29165.1.20210929.131803.0.2.25929...      416      573
# 2   1.2.276.0.95.31328.1.20210128.141041.0.2.74313...      870     1035
# 3    1.2.276.0.95.33988.1.20211103.105904.0.2.536.dcm      541      692
# 4    1.2.276.0.95.33988.1.20211103.110206.0.2.542.dcm      429      577
# 5   1.2.392.200036.9125.9.0.487527015.39393792.383...      327      519
# 6   1.2.392.200036.9125.9.0.487528295.138877440.38...      498      691
# 7   1.2.826.0.1.3680043.2.876.6339.1.2.3.201910101...     1024     1184
# 8   1.2.840.113704.7.1.0.592924817317386.163602019...      482      630
# 9   1.2.840.113704.7.1.0.592924817317386.163602019...      567      722
# 10  1.2.840.114387.217916869.44036.19338.38137.274...      319      471
# 11  1.2.840.114387.2215462629.481.16514.42000.7486...      607      765
# 12  1.2.840.114387.947080150.6976.19246.48337.1817...      532      690
# 13  1.2.840.114387.973591977.40163.17696.47493.217...      436      586
# 14  1.3.51.0.7.1652700352.15192.54351.44734.45664....      287      427
# 15  1.3.51.0.7.174306115.5298.60238.46580.43142.19...      765      924
#
#     ax1_min  ax1_max  confidence  diagnosis diagnosis_raw
# 0       771      973    0.999837          3        3, OCD
# 1       555      713    0.998813          3        3, OCD
# 2       734      899    0.999939          3        3, OCD
# 3       282      432    0.999997          3        3, OCD
# 4       745      894    1.000000          3        3, OCD
# 5       812     1005    0.985506          3        3, OCD
# 6       776      970    0.999810          3        3, OCD
# 7       618      778    0.999996          3        3, OCD
# 8       332      480    0.999997          3        3, OCD
# 9       474      628    0.999998          3        3, OCD
# 10      813      965    0.999999          3        3, OCD
# 11      468      626    0.998002          3        3, OCD
# 12      757      915    0.999993          3        3, OCD
# 13      700      851    0.999996          3        3, OCD
# 14      586      726    0.999999          3        3, OCD
# 15      867     1025    1.000000          3        3, OCD

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
detection_df.to_csv(filename_clean, index=False)
