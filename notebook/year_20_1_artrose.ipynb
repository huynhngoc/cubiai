# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/20_1, artrose.csv'
filename_clean = '../csv_detection_info_clean/20_1, artrose.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/20/1, artrose'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 29  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 30  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 31  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 32  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 33  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 34  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 35  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 36  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 37  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 38  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 39  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 40  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 41  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 42  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 44  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 45  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 46  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 47  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 48  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 49  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 50  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.7230010.3.0.3.5.1.11606741.233348646...      529      685
# 1   1.2.276.0.82.1.1.1314.669053978.192.168.20.208...     1613     1743
# 2   1.2.276.0.82.1.1.1314.669053978.192.168.20.208...     1741     1871
# 3   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.636...        0        0
# 4   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.652...     1458     1605
# 5   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.652...     1616     1771
# 6   1.2.276.0.82.1.1.1430.1889686144.192.168.5.168...     1467     1641
# 7   1.2.276.0.82.1.1.1430.332813960.192.168.1.110....     1287     1424
# 8   1.2.276.0.82.1.1.1430.641519430.192.168.1.153....     1547     1721
# 9   1.2.276.0.82.1.1.1430.641519430.192.168.1.153....     1004     1181
# 10  1.2.276.0.82.1.1.1430.784099785.192.168.1.25.6...      896     1071
# 11  1.2.276.0.82.1.1.1430.784099785.192.168.1.33.6...     1722     1912
# 12           1.2.276.0.95.16003.20200109.144616.0.dcm      787      971
# 13           1.2.276.0.95.16683.20200623.125658.0.dcm      662      831
# 14         1.2.276.0.95.16930.20200225.104451.0.0.dcm      507      637
# 15         1.2.276.0.95.16930.20200225.104622.0.0.dcm      499      630
# 16         1.2.276.0.95.17014.20200911.124939.0.0.dcm      933     1069
# 17         1.2.276.0.95.17014.20201002.102625.0.0.dcm      474      608
# 18         1.2.276.0.95.17020.20200804.143114.0.0.dcm      410      559
# 19         1.2.276.0.95.17020.20200804.143202.0.0.dcm      415      557
# 20         1.2.276.0.95.17020.20200804.143249.0.0.dcm      401      543
# 21         1.2.276.0.95.17640.20200213.103922.0.0.dcm      386      540
# 22         1.2.276.0.95.17640.20200213.105427.0.0.dcm      450      601
# 23           1.2.276.0.95.17743.20200211.135507.0.dcm      454      618
# 24           1.2.276.0.95.17743.20200615.113101.0.dcm      219      380
# 25           1.2.276.0.95.17743.20200908.115146.0.dcm      296      419
# 26           1.2.276.0.95.17743.20201204.145824.0.dcm      450      598
# 27         1.2.276.0.95.17761.20201013.143850.0.0.dcm      709      863
# 28         1.2.276.0.95.17831.20201102.111106.0.0.dcm      641      825
# 29         1.2.276.0.95.17831.20201102.112457.0.0.dcm      569      755
# 30           1.2.276.0.95.18119.20200212.183639.0.dcm      958     1154
# 31           1.2.276.0.95.18119.20200805.101245.0.dcm      822      998
# 32           1.2.276.0.95.18119.20200805.101522.0.dcm     1132     1323
# 33         1.2.276.0.95.18241.20200123.140553.0.0.dcm      930     1111
# 34           1.2.276.0.95.28994.20200311.111204.0.dcm     1499     1647
# 35           1.2.276.0.95.28994.20200311.111449.0.dcm     1446     1600
# 36           1.2.276.0.95.28994.20200311.111542.0.dcm     1485     1638
# 37           1.2.276.0.95.28994.20200311.112116.0.dcm     1790     1939
# 38           1.2.276.0.95.28994.20200311.112300.0.dcm     1607     1759
# 39           1.2.276.0.95.28994.20200311.112348.0.dcm     1613     1764
# 40           1.2.276.0.95.28994.20200717.133740.0.dcm     1360     1488
# 41           1.2.276.0.95.28994.20200717.133853.0.dcm        0        0
# 42           1.2.276.0.95.28994.20200717.134058.0.dcm        0        0
# 43           1.2.276.0.95.28994.20200717.134135.0.dcm     1377     1527
# 44           1.2.276.0.95.28994.20200717.134806.0.dcm        0        0
# 45           1.2.276.0.95.28994.20200717.135149.0.dcm     1343     1489
# 46           1.2.276.0.95.28994.20200717.135233.0.dcm     1378     1520
# 47           1.2.276.0.95.29091.20200707.100737.0.dcm      791      962
# 48  1.2.276.0.95.29165.1.20201216.95532.0.2.20630.dcm      982     1149
# 49            1.2.276.0.95.29165.20200525.90328.0.dcm      513      678
# 50           1.2.276.0.95.29373.20200505.123330.0.dcm      857     1009
#
#     ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 0       739      896    1.000000    20          1    1, artrose
# 1      1837     1967    0.778734    20          1    1, artrose
# 2      1777     1906    0.352781    20          1    1, artrose
# 3         0        0    0.000000    20          1    1, artrose
# 4       711      857    0.997802    20          1    1, artrose
# 5      1337     1491    0.998693    20          1    1, artrose
# 6      1614     1788    0.999998    20          1    1, artrose
# 7      1436     1573    0.999963    20          1    1, artrose
# 8      1284     1458    0.999987    20          1    1, artrose
# 9      1337     1515    0.999997    20          1    1, artrose
# 10     1243     1418    0.999703    20          1    1, artrose
# 11     1427     1620    0.913731    20          1    1, artrose
# 12      565      749    0.999993    20          1    1, artrose
# 13      778      948    0.997365    20          1    1, artrose
# 14      685      816    0.999912    20          1    1, artrose
# 15      690      820    0.999985    20          1    1, artrose
# 16      751      887    0.999645    20          1    1, artrose
# 17      448      582    0.999899    20          1    1, artrose
# 18      630      779    0.999908    20          1    1, artrose
# 19      177      320    0.999992    20          1    1, artrose
# 20      394      536    0.999992    20          1    1, artrose
# 21      543      698    0.999693    20          1    1, artrose
# 22      512      663    0.999971    20          1    1, artrose
# 23      836     1000    0.951524    20          1    1, artrose
# 24      692      852    0.712565    20          1    1, artrose
# 25      488      610    0.996909    20          1    1, artrose
# 26      320      468    0.624591    20          1    1, artrose
# 27     1316     1470    0.999761    20          1    1, artrose
# 28     1293     1479    0.999989    20          1    1, artrose
# 29     1460     1645    0.999759    20          1    1, artrose
# 30      953     1150    0.996899    20          1    1, artrose
# 31     1149     1324    0.999670    20          1    1, artrose
# 32     1042     1232    0.644307    20          1    1, artrose
# 33     1034     1215    0.999989    20          1    1, artrose
# 34     1546     1694    0.952834    20          1    1, artrose
# 35     1503     1657    0.684267    20          1    1, artrose
# 36     1457     1610    0.987574    20          1    1, artrose
# 37     1370     1519    0.990696    20          1    1, artrose
# 38     1393     1545    0.984824    20          1    1, artrose
# 39     1391     1542    0.994997    20          1    1, artrose
# 40     1583     1711    0.972033    20          1    1, artrose
# 41        0        0    0.000000    20          1    1, artrose
# 42        0        0    0.000000    20          1    1, artrose
# 43     1564     1712    0.413085    20          1    1, artrose
# 44        0        0    0.000000    20          1    1, artrose
# 45     1634     1777    0.585707    20          1    1, artrose
# 46     1606     1747    0.447922    20          1    1, artrose
# 47      613      785    0.999999    20          1    1, artrose
# 48      596      762    0.750951    20          1    1, artrose
# 49      882     1047    0.999993    20          1    1, artrose
# 50      625      777    0.999997    20          1    1, artrose

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5]
# Out:
#                                             base_path  \
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 41  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 42  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 44  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 46  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 2   1.2.276.0.82.1.1.1314.669053978.192.168.20.208...     1741     1871
# 3   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.636...        0        0
# 41           1.2.276.0.95.28994.20200717.133853.0.dcm        0        0
# 42           1.2.276.0.95.28994.20200717.134058.0.dcm        0        0
# 43           1.2.276.0.95.28994.20200717.134135.0.dcm     1377     1527
# 44           1.2.276.0.95.28994.20200717.134806.0.dcm        0        0
# 46           1.2.276.0.95.28994.20200717.135233.0.dcm     1378     1520
#
#     ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 2      1777     1906    0.352781    20          1    1, artrose
# 3         0        0    0.000000    20          1    1, artrose
# 41        0        0    0.000000    20          1    1, artrose
# 42        0        0    0.000000    20          1    1, artrose
# 43     1564     1712    0.413085    20          1    1, artrose
# 44        0        0    0.000000    20          1    1, artrose
# 46     1606     1747    0.447922    20          1    1, artrose

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()
# Out:
# C:\NMBU\Miniconda3\envs\deoxys\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   """
# C:\NMBU\Miniconda3\envs\deoxys\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   """

# %% [markdown]
# ## Remove bad detection items

# %%
remove_indice = [1,2,3,41,42,44]
detection_df[~detection_df.index.isin(remove_indice)]
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 29  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 30  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 31  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 32  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 33  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 34  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 35  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 36  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 37  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 38  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 39  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 40  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 45  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 46  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 47  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 48  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 49  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 50  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.7230010.3.0.3.5.1.11606741.233348646...      529      685
# 4   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.652...     1458     1605
# 5   1.2.276.0.82.1.1.1430.1216030460.10.0.0.10.652...     1616     1771
# 6   1.2.276.0.82.1.1.1430.1889686144.192.168.5.168...     1467     1641
# 7   1.2.276.0.82.1.1.1430.332813960.192.168.1.110....     1287     1424
# 8   1.2.276.0.82.1.1.1430.641519430.192.168.1.153....     1547     1721
# 9   1.2.276.0.82.1.1.1430.641519430.192.168.1.153....     1004     1181
# 10  1.2.276.0.82.1.1.1430.784099785.192.168.1.25.6...      896     1071
# 11  1.2.276.0.82.1.1.1430.784099785.192.168.1.33.6...     1722     1912
# 12           1.2.276.0.95.16003.20200109.144616.0.dcm      787      971
# 13           1.2.276.0.95.16683.20200623.125658.0.dcm      662      831
# 14         1.2.276.0.95.16930.20200225.104451.0.0.dcm      507      637
# 15         1.2.276.0.95.16930.20200225.104622.0.0.dcm      499      630
# 16         1.2.276.0.95.17014.20200911.124939.0.0.dcm      933     1069
# 17         1.2.276.0.95.17014.20201002.102625.0.0.dcm      474      608
# 18         1.2.276.0.95.17020.20200804.143114.0.0.dcm      410      559
# 19         1.2.276.0.95.17020.20200804.143202.0.0.dcm      415      557
# 20         1.2.276.0.95.17020.20200804.143249.0.0.dcm      401      543
# 21         1.2.276.0.95.17640.20200213.103922.0.0.dcm      386      540
# 22         1.2.276.0.95.17640.20200213.105427.0.0.dcm      450      601
# 23           1.2.276.0.95.17743.20200211.135507.0.dcm      454      618
# 24           1.2.276.0.95.17743.20200615.113101.0.dcm      219      380
# 25           1.2.276.0.95.17743.20200908.115146.0.dcm      296      419
# 26           1.2.276.0.95.17743.20201204.145824.0.dcm      450      598
# 27         1.2.276.0.95.17761.20201013.143850.0.0.dcm      709      863
# 28         1.2.276.0.95.17831.20201102.111106.0.0.dcm      641      825
# 29         1.2.276.0.95.17831.20201102.112457.0.0.dcm      569      755
# 30           1.2.276.0.95.18119.20200212.183639.0.dcm      958     1154
# 31           1.2.276.0.95.18119.20200805.101245.0.dcm      822      998
# 32           1.2.276.0.95.18119.20200805.101522.0.dcm     1132     1323
# 33         1.2.276.0.95.18241.20200123.140553.0.0.dcm      930     1111
# 34           1.2.276.0.95.28994.20200311.111204.0.dcm     1499     1647
# 35           1.2.276.0.95.28994.20200311.111449.0.dcm     1446     1600
# 36           1.2.276.0.95.28994.20200311.111542.0.dcm     1485     1638
# 37           1.2.276.0.95.28994.20200311.112116.0.dcm     1790     1939
# 38           1.2.276.0.95.28994.20200311.112300.0.dcm     1607     1759
# 39           1.2.276.0.95.28994.20200311.112348.0.dcm     1613     1764
# 40           1.2.276.0.95.28994.20200717.133740.0.dcm     1360     1488
# 43           1.2.276.0.95.28994.20200717.134135.0.dcm     1377     1527
# 45           1.2.276.0.95.28994.20200717.135149.0.dcm     1343     1489
# 46           1.2.276.0.95.28994.20200717.135233.0.dcm     1378     1520
# 47           1.2.276.0.95.29091.20200707.100737.0.dcm      791      962
# 48  1.2.276.0.95.29165.1.20201216.95532.0.2.20630.dcm      982     1149
# 49            1.2.276.0.95.29165.20200525.90328.0.dcm      513      678
# 50           1.2.276.0.95.29373.20200505.123330.0.dcm      857     1009
#
#     ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 0       739      896    1.000000    20          1    1, artrose
# 4       711      857    0.997802    20          1    1, artrose
# 5      1337     1491    0.998693    20          1    1, artrose
# 6      1614     1788    0.999998    20          1    1, artrose
# 7      1436     1573    0.999963    20          1    1, artrose
# 8      1284     1458    0.999987    20          1    1, artrose
# 9      1337     1515    0.999997    20          1    1, artrose
# 10     1243     1418    0.999703    20          1    1, artrose
# 11     1427     1620    0.913731    20          1    1, artrose
# 12      565      749    0.999993    20          1    1, artrose
# 13      778      948    0.997365    20          1    1, artrose
# 14      685      816    0.999912    20          1    1, artrose
# 15      690      820    0.999985    20          1    1, artrose
# 16      751      887    0.999645    20          1    1, artrose
# 17      448      582    0.999899    20          1    1, artrose
# 18      630      779    0.999908    20          1    1, artrose
# 19      177      320    0.999992    20          1    1, artrose
# 20      394      536    0.999992    20          1    1, artrose
# 21      543      698    0.999693    20          1    1, artrose
# 22      512      663    0.999971    20          1    1, artrose
# 23      836     1000    0.951524    20          1    1, artrose
# 24      692      852    0.712565    20          1    1, artrose
# 25      488      610    0.996909    20          1    1, artrose
# 26      320      468    0.624591    20          1    1, artrose
# 27     1316     1470    0.999761    20          1    1, artrose
# 28     1293     1479    0.999989    20          1    1, artrose
# 29     1460     1645    0.999759    20          1    1, artrose
# 30      953     1150    0.996899    20          1    1, artrose
# 31     1149     1324    0.999670    20          1    1, artrose
# 32     1042     1232    0.644307    20          1    1, artrose
# 33     1034     1215    0.999989    20          1    1, artrose
# 34     1546     1694    0.952834    20          1    1, artrose
# 35     1503     1657    0.684267    20          1    1, artrose
# 36     1457     1610    0.987574    20          1    1, artrose
# 37     1370     1519    0.990696    20          1    1, artrose
# 38     1393     1545    0.984824    20          1    1, artrose
# 39     1391     1542    0.994997    20          1    1, artrose
# 40     1583     1711    0.972033    20          1    1, artrose
# 43     1564     1712    0.413085    20          1    1, artrose
# 45     1634     1777    0.585707    20          1    1, artrose
# 46     1606     1747    0.447922    20          1    1, artrose
# 47      613      785    0.999999    20          1    1, artrose
# 48      596      762    0.750951    20          1    1, artrose
# 49      882     1047    0.999993    20          1    1, artrose
# 50      625      777    0.999997    20          1    1, artrose

# %%
new_detection_df = detection_df[~detection_df.index.isin(remove_indice)]

# %%
new_detection_df.to_csv(filename_clean, index=False)
