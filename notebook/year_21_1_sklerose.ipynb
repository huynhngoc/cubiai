# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/21_1, sklerose.csv'
filename_clean = '../csv_detection_info_clean/21_1, sklerose.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/21/1, sklerose'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0          1.2.276.0.95.17831.20210713.102418.0.0.dcm      745      936
# 1          1.2.276.0.95.17831.20210713.102747.0.0.dcm      797      981
# 2            1.2.276.0.95.32053.20220106.110138.0.dcm      196      354
# 3            1.2.276.0.95.32053.20220106.110220.0.dcm      318      480
# 4            1.2.276.0.95.32121.20210621.133245.0.dcm      992     1170
# 5            1.2.276.0.95.32121.20211209.193214.0.dcm     1044     1235
# 6            1.2.276.0.95.32121.20211209.193437.0.dcm     1162     1347
# 7            1.2.276.0.95.32277.20210922.112301.0.dcm      396      525
# 8            1.2.276.0.95.32277.20210922.112329.0.dcm      367      498
# 9   1.2.276.0.95.32997.1.20210419.100227.0.2.1092.dcm     1474     1613
# 10   1.2.276.0.95.32997.1.20210419.93429.0.2.1083.dcm     1543     1674
# 11  1.2.276.0.95.33405.1.20211020.104133.0.2.3595.dcm     1241     1399
# 12  1.2.276.0.95.33405.1.20211020.104519.0.2.3600.dcm     1328     1489
# 13   1.2.276.0.95.33411.1.20211103.132334.0.2.703.dcm      547      709
# 14   1.2.276.0.95.33411.1.20211103.132449.0.2.704.dcm      490      658
# 15  1.2.276.0.95.33458.1.20211116.130145.0.2.3912.dcm      753      909
# 16  1.2.276.0.95.33458.1.20211116.130310.0.2.3913.dcm      929     1084
# 17  1.2.392.200036.9107.500.220.18951.20210429.153...      914     1047
# 18  1.2.392.200036.9125.4.0.1075934985.1660964864....      246      383
# 19  1.2.392.200036.9125.4.0.1075934985.1761628160....      402      541
# 20  1.2.392.200036.9125.4.0.1075934985.1862291456....      402      531
# 21  1.2.392.200036.9125.4.0.1814166178.2969587712....      717      833
# 22  1.2.392.200036.9125.4.0.1814166434.3070251008....      743      860
# 23  1.2.392.200036.9125.4.0.1814166434.3271577600....     1192     1309
# 24  1.2.392.200036.9125.4.0.924920828.453043984.30...      420      574
# 25  1.2.840.114387.1122818637.16351.19867.38214.63...      512      662
# 26  1.2.840.114387.2300997122.802.16749.41445.6283...      653      829
# 27  1.3.51.0.7.13062730451.19454.9799.34890.63729....      410      639
# 28  1.3.51.0.7.13455618030.37780.62019.37531.34603...      575      695
#
#     ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 0      1525     1716    0.994690    21          1   1, sklerose
# 1      1556     1740    0.985575    21          1   1, sklerose
# 2       626      785    0.999983    21          1   1, sklerose
# 3       519      681    0.999988    21          1   1, sklerose
# 4      1279     1457    0.999964    21          1   1, sklerose
# 5       707      898    0.999849    21          1   1, sklerose
# 6       793      978    0.999994    21          1   1, sklerose
# 7       518      646    0.996424    21          1   1, sklerose
# 8       542      673    0.999633    21          1   1, sklerose
# 9      1614     1753    0.999963    21          1   1, sklerose
# 10     1552     1683    0.999886    21          1   1, sklerose
# 11     1249     1408    0.997525    21          1   1, sklerose
# 12     1214     1375    0.996532    21          1   1, sklerose
# 13     1010     1173    0.999995    21          1   1, sklerose
# 14     1080     1248    0.999999    21          1   1, sklerose
# 15     1346     1503    0.999999    21          1   1, sklerose
# 16     1015     1170    0.999988    21          1   1, sklerose
# 17      972     1106    0.999984    21          1   1, sklerose
# 18      745      882    0.999527    21          1   1, sklerose
# 19      751      890    0.999911    21          1   1, sklerose
# 20      848      977    0.999953    21          1   1, sklerose
# 21      815      930    0.977247    21          1   1, sklerose
# 22      850      966    0.996657    21          1   1, sklerose
# 23      759      875    0.995005    21          1   1, sklerose
# 24      488      641    1.000000    21          1   1, sklerose
# 25      931     1081    1.000000    21          1   1, sklerose
# 26      524      700    0.999999    21          1   1, sklerose
# 27      924     1154    0.993908    21          1   1, sklerose
# 28      505      625    0.999953    21          1   1, sklerose

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
remove_indice = [13, 24, 28, 29, 30, 59, 85, 92]
detection_df[~detection_df.index.isin(remove_indice)]
# Out:
#                                              base_path  \
# 0    //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1    //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2    //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3    //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4    //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# ..                                                 ...
# 206  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 207  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 208  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 209  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 210  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                               filename  ax0_min  ax0_max  \
# 0    1.2.276.0.7230010.3.0.3.5.1.12915466.275122826...      436      575
# 1    1.2.276.0.7230010.3.0.3.5.1.12915467.308787911...      327      466
# 2    1.2.276.0.82.1.1.1314.1304108018.192.168.1.48....     1588     1746
# 3    1.2.276.0.82.1.1.1430.669053978.192.168.20.148...     1320     1504
# 4             1.2.276.0.95.16003.20210920.105115.0.dcm      333      570
# ..                                                 ...      ...      ...
# 206  1.3.51.0.7.811581196.5821.63566.37889.29771.29...      642      801
# 207  1.3.51.0.7.816869595.63744.15426.42854.50530.1...      776      981
# 208  1.3.51.0.7.903272440.15569.57677.47066.26860.4...      777      973
# 209  1.3.6.1.4.1.19179.1.1164174184218686.3.18993.1...      791      937
# 210  1.3.6.1.4.1.19179.1.1164174184218686.3.28078.1...      772      915
#
#      ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 0        556      695    0.999935    21          1    1, artrose
# 1        904     1043    0.999985    21          1    1, artrose
# 2       1806     1964    0.999988    21          1    1, artrose
# 3       1109     1293    0.999995    21          1    1, artrose
# 4        887     1123    0.996126    21          1    1, artrose
# ..       ...      ...         ...   ...        ...           ...
# 206      540      699    1.000000    21          1    1, artrose
# 207     1348     1553    0.998437    21          1    1, artrose
# 208     1676     1872    0.999926    21          1    1, artrose
# 209      719      865    0.999978    21          1    1, artrose
# 210      802      944    0.999990    21          1    1, artrose
#
# [203 rows x 10 columns]

# %%
new_detection_df = detection_df[~detection_df.index.isin(remove_indice)]

# %%
new_detection_df.to_csv(filename_clean, index=False)
