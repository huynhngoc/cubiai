# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/18_2, primaerlesjon.csv'
filename_clean = '../csv_detection_info_clean/18_2, primaerlesjon.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/18/2, primaerlesjon'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 29  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 30  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 31  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 32  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 33  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 34  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 35  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 36  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 37  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 38  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 39  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 40  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 41  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 42  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 44  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 45  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 46  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 47  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.82.1.1.1430.1638344853.172.16.123.30...      906     1118
# 1   1.2.276.0.82.1.1.1430.1638344853.172.16.123.30...     1107     1309
# 2          1.2.276.0.95.17743.20180829.121814.0.0.dcm      911     1150
# 3          1.2.276.0.95.17761.20180531.124201.0.0.dcm      411      569
# 4          1.2.276.0.95.18147.20181112.125306.0.0.dcm     1096     1298
# 5            1.2.276.0.95.29165.20180405.115846.0.dcm      780      958
# 6   1.2.392.200036.9107.500.220.55321.20180816.140...     2013     2272
# 7   1.2.392.200036.9125.4.0.1629170473.2130857984....      675      803
# 8   1.2.392.200036.9125.9.0.253447478.2063623168.1...     1085     1318
# 9   1.2.392.200036.9125.9.0.437223542.442049280.21...     1210     1412
# 10  1.2.392.200036.9125.9.0.437235443.259925248.25...      860     1070
# 11  1.2.392.200036.9125.9.0.437239415.205456152.64...      560      716
# 12  1.2.392.200036.9125.9.0.437239415.230490904.64...      326      493
# 13  1.2.826.0.1.3680043.2.876.6339.1.2.3.201810041...      777      939
# 14  1.2.840.114062.2.127.0.0.1.2018.11.26.8.41.3.2...     1194     1362
# 15  1.2.840.114062.4.10.100.38.141.2018.8.6.11.30....      958     1140
# 16  1.2.840.114387.1707899273.38895.17933.43002.24...      480      622
# 17  1.2.840.114387.2780379090.22377.19135.39697.18...      632      817
# 18  1.2.840.114387.614449418.50965.19997.39517.302...      642      781
# 19  1.2.840.114387.980039511.23948.17152.48181.258...      482      651
# 20  1.3.12.2.1107.5.3.56.10369.11.2018041814551904...      218      359
# 12      496      663    0.999998    18          2  2, primaerlesjon
# 13      938     1100    0.999999    18          2  2, primaerlesjon
# 14     1251     1419    0.999988    18          2  2, primaerlesjon
# 15      916     1098    0.999580    18          2  2, primaerlesjon
# 16      829      971    0.999998    18          2  2, primaerlesjon
# 17      722      908    0.999865    18          2  2, primaerlesjon
# 18      699      838    0.999992    18          2  2, primaerlesjon
# 19      416      585    0.999572    18          2  2, primaerlesjon
# 20      576      716    0.999995    18          2  2, primaerlesjon
# 21      852     1011    0.999998    18          2  2, primaerlesjon
# 22      510      662    0.999999    18          2  2, primaerlesjon
# 23      591      742    0.999999    18          2  2, primaerlesjon
# 24      807      944    1.000000    18          2  2, primaerlesjon
# 25     1054     1195    0.999998    18          2  2, primaerlesjon
# 26     1032     1239    0.974601    18          2  2, primaerlesjon
# 27      575      661    0.998428    18          2  2, primaerlesjon
# 28      818      987    0.999999    18          2  2, primaerlesjon
# 29     1240     1491    0.986468    18          2  2, primaerlesjon
# 30     1267     1472    0.999670    18          2  2, primaerlesjon
# 31     1188     1437    0.999320    18          2  2, primaerlesjon
# 32     1827     2055    0.986075    18          2  2, primaerlesjon
# 33      778      952    1.000000    18          2  2, primaerlesjon
# 34      989     1149    0.999998    18          2  2, primaerlesjon
# 35     2062     2244    0.999996    18          2  2, primaerlesjon
# 36     1070     1273    0.998082    18          2  2, primaerlesjon
# 37     1292     1555    0.987764    18          2  2, primaerlesjon
# 38     1224     1363    0.999999    18          2  2, primaerlesjon
# 39      964     1149    0.999995    18          2  2, primaerlesjon
# 40     2231     2425    0.999870    18          2  2, primaerlesjon
# 41     1179     1388    0.998901    18          2  2, primaerlesjon
# 42     1185     1442    0.999573    18          2  2, primaerlesjon
# 43      936     1169    0.999176    18          2  2, primaerlesjon
# 44      701      939    0.993537    18          2  2, primaerlesjon
# 45     1832     2112    0.955146    18          2  2, primaerlesjon
# 46     1216     1419    0.995067    18          2  2, primaerlesjon
# 47     1972     2201    0.997858    18          2  2, primaerlesjon

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
detection_df.to_csv(filename_clean, index=False)
