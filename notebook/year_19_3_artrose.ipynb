# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/19_3, artrose.csv'
filename_clean = '../csv_detection_info_clean/19_3, artrose.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/19/3, artrose'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 29  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 30  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 31  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 32  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 33  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 34  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 35  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 36  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 37  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 38  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 39  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 40  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 41  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 42  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 44  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 45  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 46  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 47  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 48  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 49  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 50  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 51  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 52  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 53  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 54  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 55  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 56  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.82.1.1.1430.168701517.192.168.1.129....      965     1153
# 1            1.2.276.0.95.16003.20190605.155829.0.dcm      288      435
# 2            1.2.276.0.95.16003.20190605.160619.0.dcm      347      498
# 3            1.2.276.0.95.16003.20190605.161800.0.dcm      296      441
# 4          1.2.276.0.95.17065.20190904.134500.0.0.dcm     1265     1458
# 5          1.2.276.0.95.17065.20190904.134858.0.0.dcm     1095     1281
# 6          1.2.276.0.95.17065.20190904.135321.0.0.dcm     1305     1490
# 7            1.2.276.0.95.29487.20190130.113103.0.dcm      834      986
# 8            1.2.276.0.95.29487.20190709.144129.0.dcm      390      518
# 9            1.2.276.0.95.31328.20190826.140516.0.dcm      424      572
# 10           1.2.276.0.95.31690.20190621.133255.0.dcm      542      776
# 11           1.2.276.0.95.31690.20190621.133630.0.dcm      859     1046
# 12           1.2.276.0.95.32121.20191114.192438.0.dcm     1983     2224
# 13           1.2.276.0.95.32121.20191114.193903.0.dcm     1768     2007
# 14  1.2.392.200036.9107.500.220.91546.20190522.120...     1951     2197
# 15  1.2.392.200036.9125.4.0.1260220781.755033872.3...      665      820
# 16  1.2.392.200036.9125.4.0.1260239470.956360464.3...      259      409
# 17  1.2.392.200036.9125.9.0.470746813.551694336.94...      916     1088
# 18  1.2.392.200036.9125.9.0.487581265.154665060.12...     1218     1367
# 19  1.2.392.200036.9125.9.0.487581265.175833188.12...     1030     1181
# 20  1.2.392.200036.9125.9.0.487582033.234094692.12...     1051     1198
# 21  1.2.826.0.1.3680043.2.876.6680.1.2.3.201903201...     1142     1315
# 22  1.2.826.0.1.3680043.2.876.8526.3.5.1.201908281...      855     1022
# 23  1.2.840.114062.4.10.100.38.107.2018.12.19.9.23...     1049     1210
# 11      491      677    0.990919    19          3    3, artrose
# 12     1305     1545    0.981273    19          3    3, artrose
# 13     1380     1618    0.346333    19          3    3, artrose
# 14     1648     1895    0.990048    19          3    3, artrose
# 15      459      613    0.996615    19          3    3, artrose
# 16      373      524    0.997908    19          3    3, artrose
# 17     1507     1678    0.999979    19          3    3, artrose
# 18      905     1055    0.999978    19          3    3, artrose
# 19      643      795    0.975047    19          3    3, artrose
# 20      667      814    0.997925    19          3    3, artrose
# 21     1172     1345    0.486485    19          3    3, artrose
# 22      503      671    0.999534    19          3    3, artrose
# 23      948     1110    0.999987    19          3    3, artrose
# 24      913     1086    0.760262    19          3    3, artrose
# 25      895     1062    0.999436    19          3    3, artrose
# 26      735      896    0.999910    19          3    3, artrose
# 27      975     1145    0.999995    19          3    3, artrose
# 28     1042     1200    0.999998    19          3    3, artrose
# 29     1422     1605    0.998799    19          3    3, artrose
# 30     1816     2040    0.992998    19          3    3, artrose
# 31     1128     1377    0.997900    19          3    3, artrose
# 32     1318     1480    0.783072    19          3    3, artrose
# 33     1101     1277    0.853666    19          3    3, artrose
# 34     1280     1426    0.968620    19          3    3, artrose
# 35     1441     1668    0.955356    19          3    3, artrose
# 36     1315     1471    1.000000    19          3    3, artrose
# 37     2006     2248    0.995891    19          3    3, artrose
# 38      536      673    0.999999    19          3    3, artrose
# 39     1366     1612    0.998070    19          3    3, artrose
# 40     1039     1192    0.999988    19          3    3, artrose
# 41     1896     2128    0.972583    19          3    3, artrose
# 42      904     1053    0.999916    19          3    3, artrose
# 43     1078     1235    1.000000    19          3    3, artrose
# 44      922     1084    0.999989    19          3    3, artrose
# 45     1353     1539    0.999304    19          3    3, artrose
# 46     1220     1403    0.986616    19          3    3, artrose
# 47     1962     2198    0.995509    19          3    3, artrose
# 48     1592     1832    0.997699    19          3    3, artrose
# 49     1277     1431    0.999999    19          3    3, artrose
# 50     1065     1218    0.999999    19          3    3, artrose
# 51     2591     2820    0.913585    19          3    3, artrose
# 52     1509     1732    0.425743    19          3    3, artrose
# 53     1647     1841    0.999325    19          3    3, artrose
# 54     2084     2285    0.998766    19          3    3, artrose
# 55     1455     1634    0.999998    19          3    3, artrose
# 56     1371     1524    1.000000    19          3    3, artrose

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([13, 21, 52], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
detection_df.to_csv(filename_clean, index=False)
