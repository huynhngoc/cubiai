# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/21_3, UAP.csv'
filename_clean = '../csv_detection_info_clean/21_3, UAP.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/21/3, UAP'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0            1.2.276.0.95.18290.20210507.121859.0.dcm      488      724
# 1            1.2.276.0.95.18290.20210507.122108.0.dcm      377      619
# 2   1.2.276.0.95.31583.1.20211017.152957.0.2.3867.dcm     1047     1223
# 3   1.2.276.0.95.31583.1.20211017.153220.0.2.3868.dcm     1230     1409
# 4   1.2.276.0.95.31933.1.20210312.110751.0.2.17880...      659      837
# 5            1.2.276.0.95.32121.20210722.145247.0.dcm     1096     1302
# 6    1.2.276.0.95.33342.1.20211101.93646.0.2.5062.dcm      683      852
# 7    1.2.276.0.95.33342.1.20211101.93953.0.2.5063.dcm      569      742
# 8    1.2.276.0.95.33342.1.20211101.94216.0.2.5064.dcm      623      792
# 9    1.2.276.0.95.33342.1.20211101.94329.0.2.5065.dcm      721      886
# 10           1.2.276.0.95.33570.20210407.140448.0.dcm     1306     1488
# 11           1.2.276.0.95.33570.20210407.143814.0.dcm     1382     1558
# 12  1.2.392.200036.9107.500.220.12942.20210114.110...      395      517
# 13  1.2.392.200036.9125.9.0.537879287.161031424.25...      878     1087
# 14  1.2.840.114387.325720974.33505.16720.39402.224...      499      663
# 15  1.3.51.0.7.11509733740.30235.42304.35376.51605...      774     1021
# 16  1.3.51.0.7.12612017091.18887.15689.44225.45101...     1011     1251
# 17  1.3.51.0.7.13768584796.33191.59971.42254.64851...      552      786
# 18  1.3.51.0.7.1482170625.46370.35403.48966.22022....      284      452
# 19  1.3.51.0.7.1620489209.15919.4679.41063.56152.1...      890     1135
# 20  1.3.51.0.7.1888361744.52617.324.44477.3646.473...      368      575
# 21  1.3.51.0.7.3784861779.43076.30030.39248.13938....      916     1167
# 22  1.3.51.0.7.3853568718.24653.64590.34164.7437.4...      974     1125
#
#     ax1_min  ax1_max  confidence  year  diagnosis diagnosis_raw
# 0       611      849    0.623433    21          3        3, UAP
# 1       495      734    0.426749    21          3        3, UAP
# 2       984     1159    0.999953    21          3        3, UAP
# 3       730      909    0.999991    21          3        3, UAP
# 4      1220     1397    0.999994    21          3        3, UAP
# 5       686      893    0.999987    21          3        3, UAP
# 6      1456     1626    0.999990    21          3        3, UAP
# 7       427      600    0.999928    21          3        3, UAP
# 8       394      563    0.999876    21          3        3, UAP
# 9       242      408    0.999978    21          3        3, UAP
# 10     1468     1649    1.000000    21          3        3, UAP
# 11     1524     1701    0.999922    21          3        3, UAP
# 12      772      895    0.999686    21          3        3, UAP
# 13      606      814    0.999366    21          3        3, UAP
# 14      414      579    1.000000    21          3        3, UAP
# 15     1726     1972    0.989792    21          3        3, UAP
# 16     1678     1921    0.999403    21          3        3, UAP
# 17      530      766    0.998386    21          3        3, UAP
# 18      743      912    0.999997    21          3        3, UAP
# 19     1718     1967    0.998796    21          3        3, UAP
# 20      699      906    0.999827    21          3        3, UAP
# 21     1631     1881    0.999858    21          3        3, UAP
# 22     1468     1620    0.999997    21          3        3, UAP

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([1], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
detection_df.to_csv(filename_clean, index=False)
