# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/20_2, primaerlesjon.csv'
filename_clean = '../csv_detection_info_clean/20_2, primaerlesjon.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/20/2, primaerlesjon'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# ..                                                ...
# 69  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 70  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 71  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 72  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 73  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.7230010.3.0.3.5.1.11559663.212476485...      424      548
# 1   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....     1129     1290
# 2   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....     1020     1185
# 3   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....      990     1157
# 4   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....      950     1115
# ..                                                ...      ...      ...
# 69  1.3.51.0.7.3825699428.13986.26441.36970.18406....      478      596
# 70  1.3.51.0.7.3985988110.45432.21826.43424.24773....      171      298
# 71  1.3.51.0.7.45484348.14648.23366.40330.59676.38...      707      857
# 72  1.3.51.0.7.455129284.26738.39239.33089.12533.1...     1686     1834
# 73  1.3.51.0.7.790048903.5650.1357.42022.54185.597...      308      462
#
#     ax1_min  ax1_max  confidence  year  diagnosis     diagnosis_raw
# 0       414      538    0.999857    20          2  2, primaerlesjon
# 1      1544     1704    0.999985    20          2  2, primaerlesjon
# 2      1467     1633    0.999965    20          2  2, primaerlesjon
# 3      1674     1840    0.999998    20          2  2, primaerlesjon
# 4      1373     1538    0.999999    20          2  2, primaerlesjon
# ..      ...      ...         ...   ...        ...               ...
# 69      412      529    0.968814    20          2  2, primaerlesjon
# 70      346      472    0.703405    20          2  2, primaerlesjon
# 71     1106     1256    0.999128    20          2  2, primaerlesjon
# 72      732      881    0.999869    20          2  2, primaerlesjon
# 73      520      674    0.999998    20          2  2, primaerlesjon
#
# [74 rows x 10 columns]

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5]
# Out:
#                                             base_path  \
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                     filename  ax0_min  ax0_max  ax1_min  \
# 13  1.2.276.0.95.29669.20200826.100220.0.dcm        0        0        0
#
#     ax1_max  confidence  year  diagnosis     diagnosis_raw
# 13        0         0.0    20          2  2, primaerlesjon

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()
# Out:
# C:\NMBU\TEMP\ipykernel_1344\89006417.py:5: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(img, 'gray')
# C:\NMBU\TEMP\ipykernel_1344\89006417.py:5: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(img, 'gray')

# %% [markdown]
# ## Remove bad detection items

# %%
remove_indice = [13]
detection_df[~detection_df.index.isin(remove_indice)]
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# ..                                                ...
# 69  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 70  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 71  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 72  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 73  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.7230010.3.0.3.5.1.11559663.212476485...      424      548
# 1   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....     1129     1290
# 2   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....     1020     1185
# 3   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....      990     1157
# 4   1.2.276.0.82.1.1.1430.1748116982.192.168.1.60....      950     1115
# ..                                                ...      ...      ...
# 69  1.3.51.0.7.3825699428.13986.26441.36970.18406....      478      596
# 70  1.3.51.0.7.3985988110.45432.21826.43424.24773....      171      298
# 71  1.3.51.0.7.45484348.14648.23366.40330.59676.38...      707      857
# 72  1.3.51.0.7.455129284.26738.39239.33089.12533.1...     1686     1834
# 73  1.3.51.0.7.790048903.5650.1357.42022.54185.597...      308      462
#
#     ax1_min  ax1_max  confidence  year  diagnosis     diagnosis_raw
# 0       414      538    0.999857    20          2  2, primaerlesjon
# 1      1544     1704    0.999985    20          2  2, primaerlesjon
# 2      1467     1633    0.999965    20          2  2, primaerlesjon
# 3      1674     1840    0.999998    20          2  2, primaerlesjon
# 4      1373     1538    0.999999    20          2  2, primaerlesjon
# ..      ...      ...         ...   ...        ...               ...
# 69      412      529    0.968814    20          2  2, primaerlesjon
# 70      346      472    0.703405    20          2  2, primaerlesjon
# 71     1106     1256    0.999128    20          2  2, primaerlesjon
# 72      732      881    0.999869    20          2  2, primaerlesjon
# 73      520      674    0.999998    20          2  2, primaerlesjon
#
# [73 rows x 10 columns]

# %%
new_detection_df = detection_df[~detection_df.index.isin(remove_indice)]

# %%
new_detection_df.to_csv(filename_clean, index=False)
