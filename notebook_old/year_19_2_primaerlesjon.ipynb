# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12,12)

# %%
# def crop(img, ax0_min, ax0_max, ax1_min, ax1_max):
#     ax0_size = ax0_max - ax0_min
#     ax1_size = ax1_max - ax1_min
#     ax0_start = int(max(0, ax0_min - ax0_size*2))
#     ax1_start = int(max(0, ax1_min - ax1_size*2))
#     cropped = img[ax0_start: ax0_start + ax0_size *
#                   5, ax1_start: ax1_start + ax1_size*5]

# %%
filename = '../csv_detection_info/19_2, primaerlesjon.csv'
filename_clean = '../csv_detection_info_clean/19_2, primaerlesjon.csv'
saved_cropped_image = '//nmbu.no/LargeFile/Project/CubiAI/preprocess/cropped/19/2, primaerlesjon'

# %%
detection_df = pd.read_csv(filename)

# %%
detection_df
# Out:
#                                             base_path  \
# 0   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 1   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 2   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 3   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 4   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 5   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 6   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 7   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 8   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 9   //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 10  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 11  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 12  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 13  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 14  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 15  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 16  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 17  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 18  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 19  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 20  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 21  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 22  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 23  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 24  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 25  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 26  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 27  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 28  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 29  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 30  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 31  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 32  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 33  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 34  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 35  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 36  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 37  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 38  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 39  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 40  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 41  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 42  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 43  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
# 44  //nmbu.no/LargeFile/Project/CubiAI/sortering/d...
#
#                                              filename  ax0_min  ax0_max  \
# 0   1.2.276.0.82.1.1.1430.1889686144.192.168.5.168...     1015     1214
# 1   1.2.392.200036.49.70469.1.20190411.134934.0.0.dcm      265      415
# 2   1.2.392.200036.49.70469.1.20190822.150548.0.0.dcm      404      569
# 3   1.2.392.200036.49.70469.1.20190822.150934.0.0.dcm      551      723
# 4   1.2.392.200036.9107.500.220.12345.20190321.125...      414      543
# 5   1.2.392.200036.9107.500.220.18951.20181126.150...     1000     1127
# 6   1.2.392.200036.9107.500.220.23269.20190912.938...      787      910
# 7   1.2.392.200036.9107.500.220.23269.20190912.941...      658      787
# 8   1.2.392.200036.9107.500.220.55321.20190520.120...     1695     1942
# 9   1.2.392.200036.9107.500.220.55321.20190520.120...     1913     2155
# 10  1.2.392.200036.9125.9.0.487558656.185515732.16...      431      569
# 11  1.2.392.200036.9125.9.0.487559168.240500436.16...      596      732
# 12  1.2.392.200036.9125.9.0.487559168.266256084.16...      577      717
# 13  1.2.826.0.1.3680043.2.876.14001.1.5.1.20181217...     1007     1160
# 14  1.2.826.0.1.3680043.2.876.14001.1.5.1.20181217...      693      845
# 15  1.2.826.0.1.3680043.2.876.5598.7.3.20190719104...      904     1065
# 16  1.2.826.0.1.3680043.2.876.5598.7.3.20190719104...      829      993
# 17  1.2.826.0.1.3680043.2.876.5598.7.3.20190719104...      863     1025
# 11      789      926    0.999913    19          2  2, primaerlesjon
# 12      890     1030    0.999982    19          2  2, primaerlesjon
# 13     1548     1701    1.000000    19          2  2, primaerlesjon
# 14     1143     1296    0.999998    19          2  2, primaerlesjon
# 15     1351     1513    0.999973    19          2  2, primaerlesjon
# 16     1304     1468    0.999972    19          2  2, primaerlesjon
# 17      983     1145    0.999985    19          2  2, primaerlesjon
# 18      964     1131    0.999983    19          2  2, primaerlesjon
# 19      723      972    0.997502    19          2  2, primaerlesjon
# 20      423      563    0.999997    19          2  2, primaerlesjon
# 21      427      574    0.999944    19          2  2, primaerlesjon
# 22      615      761    0.999983    19          2  2, primaerlesjon
# 23      965     1119    0.999999    19          2  2, primaerlesjon
# 24      549      689    0.999992    19          2  2, primaerlesjon
# 25     1682     1884    0.998179    19          2  2, primaerlesjon
# 26     1846     2052    0.999179    19          2  2, primaerlesjon
# 27      639      781    0.999998    19          2  2, primaerlesjon
# 28     1008     1214    0.999790    19          2  2, primaerlesjon
# 29     1472     1675    0.999667    19          2  2, primaerlesjon
# 30     1668     1863    0.966977    19          2  2, primaerlesjon
# 31      869     1073    0.998470    19          2  2, primaerlesjon
# 32      593      745    0.999999    19          2  2, primaerlesjon
# 33      542      700    0.999999    19          2  2, primaerlesjon
# 34     1219     1376    0.999971    19          2  2, primaerlesjon
# 35      604      753    1.000000    19          2  2, primaerlesjon
# 36     1819     2044    0.998898    19          2  2, primaerlesjon
# 37     1176     1315    0.999945    19          2  2, primaerlesjon
# 38      508      655    0.999993    19          2  2, primaerlesjon
# 39     1901     2101    0.998933    19          2  2, primaerlesjon
# 40      868     1002    0.999997    19          2  2, primaerlesjon
# 41      756      902    0.999995    19          2  2, primaerlesjon
# 42      844     1039    0.996330    19          2  2, primaerlesjon
# 43      877     1010    0.999998    19          2  2, primaerlesjon
# 44      646      776    0.999981    19          2  2, primaerlesjon

# %% [markdown]
# ### [Optional] Sort by confidence (filter out bad prediction)

# %%
# detection_df = detection_df[detection_df.confidence > 0.5]

# %%
detection_df[detection_df.confidence < 0.5].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Note that there is one case that is not good

# %% [markdown]
# ### Look at the crop images
#
# Are they reasonable, if not, mark the "weird", "wrong detected" image indice before saving it back to the clean folder

# %%
# plot every 9 of them

# %%
for id, item in detection_df.iterrows():
    fn = item['filename']
    img = np.load(saved_cropped_image + '/' + fn + '.npy')
    plt.subplot(3,3, (id%9) + 1)
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.title(str(id))
    
    if (id%9) == 8:
        plt.show()
        
plt.show()

# %% [markdown]
# ## Remove bad detection items

# %%
detection_df.to_csv(filename_clean, index=False)
